# %%
# fmt: off
# type: ignore
# ruff: noqa
# %load_ext tracerite

# %%
a = 1 + "b"  # Comment
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
def multiline_error():
    # fmt: off
    _ = (
        1
        +
        "a")
    # fmt: on


multiline_error()
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
# fmt: off
_ = (1
     +
    "a")
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
import mimetypes

t, _ = mimetypes.guess_type(123)[0]
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
max("a", 1)
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
try:
    wrongname
except NameError:
    raise RuntimeError("foo") from None
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
try:
    wrongname
except NameError:
    raise RuntimeError("foo")
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
try:
    wrongname
except NameError as e:
    try:
        raise RuntimeError("foo") from e
    except Exception as e2:
        raise AttributeError("bar")
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
try:
    wrongname
except NameError:
    0 / 0
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
try:
    wrongname
finally:
    0 / 0
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
input()
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
try:
    raise KeyboardInterrupt("quick exit")
finally:
    ...
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
"a" <= 2
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...

# %%
raise Exception("""Brief.

    1 2 3
    i i i
""")
# Out:
# 《E Builder》
# <div class=tracerite><script>const scrollto=id=>document.getElementById(id).scrollIntoView({behavior:'smooth',block:'nearest',inline:'start'})</script><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# ...
