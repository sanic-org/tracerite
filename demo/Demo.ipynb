# %%
# fmt: off
# type: ignore
# ruff: noqa
# %load_ext tracerite

# %%
a = 1 + "b"  # Comment
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-1WncNiQCN_WWGf9p')</script></div>

# %%
def multiline_error():
    # fmt: off
    _ = (
        1
        +
        "a")
    # fmt: on


multiline_error()
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-NX35pM6XYZVUN9gF')</script></div>

# %%
# fmt: off
_ = (1
     +
    "a")
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-88QKg64h64KWBVEH')</script></div>

# %%
import mimetypes

file_ext = None
t = mimetypes.guess_type(file_ext)[0]
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-4FYN0AZx8vGJzuj4')</script></div>

# %%
max("a", 1)
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-holFtPSmI1C6O7dy')</script></div>

# %%
try:
    wrongname
except NameError:
    raise RuntimeError("foo") from None
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-v4YMmk4dldjCPKTp')</script></div>

# %%
try:
    wrongname
except NameError:
    raise RuntimeError("foo")
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· llT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-ZRDFhawkp3nUsy39')
# tracerite_scrollto('tb-MqdISz57mNEhnv6S')</script></div>

# %%
try:
    wrongname
except NameError as e:
    try:
        raise RuntimeError("foo") from e
    except Exception as e2:
        raise AttributeError("bar")
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· roll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-OE2_dM9gUFwNl-Uk')
# tracerite_scrollto('tb-BECf-H0rfRfhzJoQ')
# tracerite_scrollto('tb-OIjojfOvHojKfJQG')</script></div>

# %%
try:
    wrongname
except NameError:
    0 / 0
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· llT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-tM9931k3Dw5GSip9')
# tracerite_scrollto('tb-qp0mqk2s_gxINQuI')</script></div>

# %%
try:
    wrongname
finally:
    0 / 0
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· llT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-vXJA3vEeokw_RzGC')
# tracerite_scrollto('tb-NZM54BufN90Vpsp3')</script></div>

# %%
input()
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-Y2YkqfR0MoUOaPw_')</script></div>

# %%
try:
    raise KeyboardInterrupt("quick exit")
finally:
    ...
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-897fXtO78wIeqmOB')</script></div>

# %%
"a" <= 2
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-sGhk4ESf294ekkMQ')</script></div>

# %%
raise Exception("""Brief.

    1 2 3
    i i i
""")
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# /* Allow tooltip containers to overflow for proper tooltip displ ··· scrollT-=e.movementY;vPanel.scrollTop=scrollT;
#       }
#     }
#   });
#   // Initially scroll each frame-content to show all marks (centered if they fit, else from top)
#   c.querySelectorAll('.frame-content').forEach(d=>{
#     const marks=d.querySelectorAll('mark,.tracerite-tooltip,.tracerite-symbol');
#     if(marks.length){
#       let minTop=Infinity,maxBottom=0;
#       marks.forEach(m=>{
#         const top=m.offsetTop;
#         const bottom=top+m.offsetHeight;
#         if(top<minTop)minTop=top;
#         if(bottom>maxBottom)maxBottom=bottom;
#       });
#       const marksHeight=maxBottom-minTop;
#       const panelHeight=d.clientHeight;
#       // If marks fit, center them; otherwise scroll to show from first mark
#       if(marksHeight<=panelHeight){
#         const marksCenter=(minTop+maxBottom)/2;
#         d.scrollTop=marksCenter-panelHeight/2;
#       }else{
#         d.scrollTop=minTop-panelHeight*0.1;  // Small top padding
#       }
#     }
#   });
# });
# })()
#
# tracerite_scrollto('tb-pHOYYr5UDC4uQ9OD')</script></div>
