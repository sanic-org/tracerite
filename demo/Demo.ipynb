# %%
# fmt: off
# type: ignore
# ruff: noqa
# !uv pip install -e .
# %load_ext tracerite
# Out:
# Resolved 2 packages in 252ms
# Prepared 1 package in 100ms
# Uninstalled 1 package in 0.26ms
# Installed 1 package in 0.44msgf7ef32eda.d20251218 (from file
#  ~ tracerite==2.1.1.dev7+gf7ef32eda.d20251218 (from file:///home/user/tracerite)

# %%
syntax error (
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# ...

# %%
foo(
    a,
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# ...

# %%
a = 123
foo({{
    "key": ")}"
    )}}
# Out:
# 《E Builder》
# <div class=tracerite data-replace-previous=1><style>@import url('https://cdn.jsdelivr.net/npm/@fontsource/monaspace-krypton/index.css');
#
# /** TraceRite **/
# :root {
#   --tracerite-var: #8af;
#   --tracerite-type: #5c8;
#   --tracerite-val: #8af;
#   --tracerite-tab: #aaaa;
#   --tracerite-highlight: #ff08;
#   --tracerite-symbol: #ff0;
#   --tracerite-caret: #f00;
#   --tracerite-exception: gray;
#   --tracerite-tab-hover: #ddd;
#   --tracerite-tooltip: #000;
#   --tracerite-code-font: 'Monaspace Krypton', 'JetBrains Mono', 'Fira Code', 'Cascadia Code', 'Source Code Pro', 'SF Mono', 'Monaco', 'Inconsolata', 'Roboto Mono', 'Ubuntu Mono', 'Consolas', 'Courier New';
#   --tracerite-ui-font: system-ui, -apple-system, 'Segoe UI', 'Roboto', 'Ubuntu', 'Cantarell', 'Noto Sans', sans-serif;
# }
#
# .tracerite,
# .tracerite *,
# .tracerite .traceback-details table,
# .tracerite > h3 { margin: 0; padding: 0; outline: none; box-sizing: border-box; overflow: hidden; }
#
# ...

# %%
exec("foo = '")

# %%
a = 1 + "b"  # Comment

# %%
def multiline_error():
    # fmt: off
    _ = (
        1
        +
        "a")
    # fmt: on


multiline_error()

# %%
# fmt: off
_ = (1
     +
    "a")

# %%
import mimetypes

file_ext = None
t = mimetypes.guess_type(file_ext)[0]

# %%
max("a", 1)

# %%
try:
    wrongname
except NameError:
    raise RuntimeError("foo") from None

# %%
try:
    wrongname
except NameError:
    raise RuntimeError("foo")

# %%
try:
    wrongname
except NameError as e:
    try:
        raise RuntimeError("foo") from e
    except Exception as e2:
        raise AttributeError("bar")

# %%
try:
    wrongname
except NameError:
    0 / 0

# %%
try:
    wrongname
finally:
    0 / 0

# %%
input()

# %%
try:
    raise KeyboardInterrupt("quick exit")
finally:
    ...

# %%
"a" <= 2

# %%
raise Exception("""Brief.

    1 2 3
    i i i
""")
